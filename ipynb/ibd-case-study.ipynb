# %%
from cmdstanpy import CmdStanModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a768a203a952> in <module>
# ----> 1 from cmdstanpy import CmdStanModel
#
# ModuleNotFoundError: No module named 'cmdstanpy'

# %%
# !ls ../data/gevers
# Out:
# 45568_otu_table.biom                  sample-metadata.txt
# feature-table.biom                    sample_information_from_prep_1177.tsv

# %%
from biom import load_table
import pandas as pd
data_dir = '../data/gevers'
table = load_table(f'{data_dir}/feature-table.biom')
md = pd.read_table(f'{data_dir}/sample-metadata.txt')

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.heatmap(np.log(table.matrix_data.todense()+1))

# %%
import os
stan_file = os.path.join(os.getcwd(), 'nb_diff.stan')

# %%
nb_model = CmdStanModel(stan_file=bernoulli_stan)
nb_vb = nb_model.variational(data=nb_data)
